# %% [markdown]
# # Exercícios
#
# ## 1. Tamanho do Pedido de Compras
#
# Nesse exercício vamos avaliar o estoque de uma empresa. Vamos considerar que todos os produtos dessa empresa são comprados em lotes de 500 unidades.
#
# - Caso o estoque esteja abaixo de 1000 unidades, devemos fazer um pedido de 500 unidades.
# - Caso o estoque esteja abaixo de 200 unidades, devemos fazer um pedido de 1000 unidades.
#
# Defina o valor a ser pedido de cada produto para enviar ao time de compras.

# %%
estoque = [('BSA2199',396),('PPF5239',251),('BSA1212',989),('PPF2154',449),('BEB3410',241),('PPF8999',527),('EMB9591',601),('BSA2006',314),('EMB3604',469),('EMB2070',733),('PPF9018',339),('PPF1468',906),('BSA5819',291),('PPF8666',850),('BEB2983',353),('BEB5877',456),('PPF5008',963),('PPF3877',185),('PPF7321',163),('BSA8833',644),('PPF4980',421),('PPF3063',757),('BSA2089',271),('BSA8398',180),('EMB4622',515),('EMB9814',563),('PPF3784',229),('PPF2398',270),('BEB3211',181),('PPF8655',459),('PPF1874',799),('PPF8789',126),('PPF6324',375),('EMB9290',883),('BSA5516',555),('BSA8451',243),('BSA8213',423)]

# %%
pedido = [(f'{produto} - Pedido: 1000 unidades.' if unidades < 200 else f'{produto} - pedido: 500 unidades.') for produto, unidades in estoque if unidades < 1000]

print('\n'.join(pedido))
# Out:
# BSA2199 - pedido: 500 unidades.
# PPF5239 - pedido: 500 unidades.
# BSA1212 - pedido: 500 unidades.
# PPF2154 - pedido: 500 unidades.
# BEB3410 - pedido: 500 unidades.
# PPF8999 - pedido: 500 unidades.
# EMB9591 - pedido: 500 unidades.
# BSA2006 - pedido: 500 unidades.
# EMB3604 - pedido: 500 unidades.
# EMB2070 - pedido: 500 unidades.
# PPF9018 - pedido: 500 unidades.
# PPF1468 - pedido: 500 unidades.
# BSA5819 - pedido: 500 unidades.
# PPF8666 - pedido: 500 unidades.
# BEB2983 - pedido: 500 unidades.
# BEB5877 - pedido: 500 unidades.
# PPF5008 - pedido: 500 unidades.
# PPF3877 - Pedido: 1000 unidades.
# PPF7321 - Pedido: 1000 unidades.
# BSA8833 - pedido: 500 unidades.
# PPF4980 - pedido: 500 unidades.
# PPF3063 - pedido: 500 unidades.
# BSA2089 - pedido: 500 unidades.
# BSA8398 - Pedido: 1000 unidades.
# EMB4622 - pedido: 500 unidades.
# EMB9814 - pedido: 500 unidades.
# PPF3784 - pedido: 500 unidades.
# PPF2398 - pedido: 500 unidades.
# BEB3211 - Pedido: 1000 unidades.
# PPF8655 - pedido: 500 unidades.
# PPF1874 - pedido: 500 unidades.
# PPF8789 - Pedido: 1000 unidades.
# PPF6324 - pedido: 500 unidades.
# EMB9290 - pedido: 500 unidades.
# BSA5516 - pedido: 500 unidades.
# BSA8451 - pedido: 500 unidades.
# BSA8213 - pedido: 500 unidades.
