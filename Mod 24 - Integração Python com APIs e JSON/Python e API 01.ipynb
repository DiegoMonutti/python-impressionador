# %% [markdown]
# #### Pegar a Cotação Atual de Todas as Moedas

# %%
import requests
import json

cotacoes = requests.get('https://economia.awesomeapi.com.br/json/all')
cotacoes_dic = cotacoes.json()
print(cotacoes_dic)
# Out:
# {'USD': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '5.0599', 'low': '5.0559', 'varBid': '0', 'pctChange': '0', 'bid': '5.0565', 'ask': '5.0575', 'timestamp': '1680878735', 'create_date': '2023-04-07 11:45:35'}, 'USDT': {'code': 'USD', 'codein': 'BRLT', 'name': 'Dólar Americano/Real Brasileiro Turismo', 'high': '5.085', 'low': '5.085', 'varBid': '0', 'pctChange': '0', 'bid': '4.93', 'ask': '5.24', 'timestamp': '1680808440', 'create_date': '2023-04-06 16:14:00'}, 'CAD': {'code': 'CAD', 'codein': 'BRL', 'name': 'Dólar Canadense/Real Brasileiro', 'high': '3.7522', 'low': '3.7366', 'varBid': '-0.0063', 'pctChange': '-0.17', 'bid': '3.7403', 'ask': '3.743', 'timestamp': '1680899302', 'create_date': '2023-04-07 17:28:22'}, 'GBP': {'code': 'GBP', 'codein': 'BRL', 'name': 'Libra Esterlina/Real Brasileiro', 'high': '6.3023', 'low': '6.2642', 'varBid': '-0.0061', 'pctChange': '-0.1', 'bid': '6.2817', 'ask': '6.287', 'timestamp': '1680899299', 'create_date': '2023-04-07 17:28:19'}, 'ARS': {'code': 'ARS', 'codein': 'BRL', 'name': 'Peso Argentino/Real Brasileiro', 'high': '0.0239', 'low': '0.0239', 'varBid': '0', 'pctChange': '0', 'bid': '0.0239', 'ask': '0.0239', 'timestamp': '1680878735', 'create_date': '2023-04-07 11:45:35'}, 'BTC': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '143088', 'low': '141686', 'varBid': '-177', 'pctChange': '-0.12', 'bid': '142137', 'ask': '142202', 'timestamp': '1680899150', 'create_date': '2023-04-07 17:25:50'}, 'LTC': {'code': 'LTC', 'codein': 'BRL', 'name': 'Litecoin/Real Brasileiro', 'high': '463.95', 'low': '455.1', 'varBid': '-0.7', 'pctChange': '-0.15', 'bid': '459.72', 'ask': '460.73', 'timestamp': '1680899146', 'create_date': '2023-04-07 17:25:46'}, 'EUR': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '5.5277', 'low': '5.4998', 'varBid': '-0.0071', 'pctChange': '-0.13', 'bid': '5.5141', 'ask': '5.5172', 'timestamp': '1680899296', 'create_date': '2023-04-07 17:28:16'}, 'JPY': {'code': 'JPY', 'codein': 'BRL', 'name': 'Iene Japonês/Real Brasileiro', 'high': '0.03845', 'low': '0.0382', 'varBid': '-0.0001', 'pctChange': '-0.26', 'bid': '0.03828', 'ask': '0.0383', 'timestamp': '1680899306', 'create_date': '2023-04-07 17:28:26'}, 'CHF': {'code': 'CHF', 'codein': 'BRL', 'name': 'Franco Suíço/Real Brasileiro', 'high': '5.601', 'low': '5.5672', 'varBid': '-0.0031', 'pctChange': '-0.05', 'bid': '5.5861', 'ask': '5.5896', 'timestamp': '1680898712', 'create_date': '2023-04-07 17:18:32'}, 'AUD': {'code': 'AUD', 'codein': 'BRL', 'name': 'Dólar Australiano/Real Brasileiro', 'high': '3.3856', 'low': '3.3576', 'varBid': '-0.0035', 'pctChange': '-0.11', 'bid': '3.3691', 'ask': '3.3708', 'timestamp': '1680899267', 'create_date': '2023-04-07 17:27:47'}, 'CNY': {'code': 'CNY', 'codein': 'BRL', 'name': 'Yuan Chinês/Real Brasileiro', 'high': '0.7369', 'low': '0.7355', 'varBid': '0.0007', 'pctChange': '0.09', 'bid': '0.736', 'ask': '0.7361', 'timestamp': '1680897902', 'create_date': '2023-04-07 17:05:02'}, 'ILS': {'code': 'ILS', 'codein': 'BRL', 'name': 'Novo Shekel Israelense/Real Brasileiro', 'high': '1.4084', 'low': '1.3923', 'varBid': '0.0041', 'pctChange': '0.29', 'bid': '1.3993', 'ask': '1.3996', 'timestamp': '1680899283', 'create_date': '2023-04-07 17:28:03'}, 'ETH': {'code': 'ETH', 'codein': 'BRL', 'name': 'Ethereum/Real Brasileiro', 'high': '9580', 'low': '9391.22', 'varBid': '-143.97', 'pctChange': '-1.5', 'bid': '9442.76', 'ask': '9490.66', 'timestamp': '1680899300', 'create_date': '2023-04-07 17:28:20'}, 'XRP': {'code': 'XRP', 'codein': 'BRL', 'name': 'XRP/Real Brasileiro', 'high': '2.62', 'low': '2.53', 'varBid': '0.05', 'pctChange': '1.9', 'bid': '2.61', 'ask': '2.61', 'timestamp': '1680899120', 'create_date': '2023-04-07 17:25:20'}, 'DOGE': {'code': 'DOGE', 'codein': 'BRL', 'name': 'Dogecoin/Real Brasileiro', 'high': '0.46129', 'low': '0.41455', 'varBid': '-0.02245', 'pctChange': '-5.13', 'bid': '0.41534', 'ask':  ...

# %% [markdown]
# #### Qual foi a última cotação do Dólar, do Euro e do BitCoin?

# %%
print('Dólar: {}'.format(cotacoes_dic['USD']['bid']))
print('Euro: {}'.format(cotacoes_dic['EUR']['bid']))
print('Bitcoin: {}'.format(cotacoes_dic['BTC']['bid']))
# Out:
# Dólar: 5.0565
# Euro: 5.5141
# Bitcoin: 142137

# %% [markdown]
# #### Pegar a cotação dos últimos 30 dias do dólar:

# %%
cotacoes_dolar30d = requests.get('https://economia.awesomeapi.com.br/json/daily/USD-BRL/30')
cotacoes_dolar_dic = cotacoes_dolar30d.json()
#print(cotacoes_dolar_dic[2]['bid'])
lista_cotacoes_dolar = [float(item['bid']) for item in cotacoes_dolar_dic]
print(lista_cotacoes_dolar)
# Out:
# [5.0565, 5.0594, 5.034, 5.0692, 5.0619, 5.0629, 5.0624, 5.094, 5.1351, 5.1655, 5.1983, 5.2459, 5.2979, 5.2369, 5.2424, 5.2368, 5.2748, 5.2793, 5.2798, 5.2307, 5.288, 5.2534, 5.2467, 5.2166, 5.2166, 5.2166, 5.1645, 5.1453, 5.191, 5.1534]

# %% [markdown]
# #### Pegar as cotações do BitCoin de Jan/20 a Out/20

# %%
cotacoes_btc = requests.get('https://economia.awesomeapi.com.br/json/daily/BTC-BRL/200?start_date=20200101&end_date=20201031')
cotacoes_btc_dic = cotacoes_btc.json()
lista_cotacoes_btc = [float(item['bid']) for item in cotacoes_btc_dic]
lista_cotacoes_btc.reverse()
print(lista_cotacoes_btc)
print(len(lista_cotacoes_btc))
# Out:
# [35150.0, 37025.0, 36836.7, 37415.0, 37158.0, 36652.1, 36800.0, 38000.1, 40050.0, 41050.0, 41212.0, 41715.0, 43392.0, 43070.0, 46424.7, 46610.0, 47626.0, 47900.0, 48553.0, 48852.0, 49700.0, 52500.0, 57700.0, 52609.1, 52499.0, 49225.0, 49700.0, 51488.8, 54450.0, 56208.0, 53609.0, 54207.4, 55300.0, 55651.1, 55760.8, 54831.8, 51440.0, 51400.0, 51600.0, 49560.0, 49735.0, 47625.1, 49000.2, 51700.3, 50650.0, 51500.0, 50865.1, 53600.0, 54001.0, 49500.4, 50400.6, 48800.4, 48820.6, 49133.5, 48096.8, 48201.0, 49350.0, 47000.0, 48100.1, 47788.9, 47750.0, 48501.4, 49679.0, 49290.6, 50405.0, 49700.0, 49750.0, 49782.0, 50710.0, 49759.1, 49800.0, 49755.0, 49915.1, 49678.2, 49746.8, 49840.0, 49960.0, 49800.0, 49208.8, 48815.5, 48993.1, 48850.0, 49890.0, 49900.1, 50360.1, 49890.0, 49905.9, 49750.0, 49920.0, 50041.3, 50073.4, 49868.0, 49320.0, 49702.1, 49651.8, 49680.0, 49516.5, 49143.0, 49321.0, 49850.0, 49951.1, 50400.2, 50402.0, 55300.0, 56161.0, 57490.0, 57330.0, 58950.0, 61298.1, 58296.3, 59800.0, 59951.0, 61902.2, 63302.0, 63140.0, 63715.0, 63700.0, 65303.8, 62300.0, 63120.0, 63210.3, 63905.0, 64280.0, 64270.3, 67501.0, 66453.3, 65800.0, 66655.0, 65657.4, 66112.0, 66100.0, 66360.9, 63606.0, 64655.2, 63599.9, 63016.2, 62700.0, 63350.9, 64200.0, 64900.0, 61939.0, 55336.6, 56500.0, 54555.7, 55550.3, 55102.2, 54348.3, 55059.1, 55511.0, 55821.2, 55856.7, 55566.0, 56908.9, 57700.0, 58250.0, 57807.2, 59285.0, 59750.0, 59100.0, 57050.6, 57880.5, 57884.0, 59501.1, 59845.0, 59720.5, 59638.4, 60600.1, 60995.0, 60950.1, 60390.7, 60512.5, 60018.1, 60569.2, 60210.3, 59801.0, 60265.0, 61211.5, 61960.0, 62747.2, 62701.0, 63558.3, 63601.7, 64100.6, 65000.0, 64400.0, 64500.0, 64950.1, 66000.3, 66952.4, 71401.0, 72251.2, 72202.4, 73300.0, 73200.0, 73685.5, 77888.1, 76550.1, 77950.2, 78101.0, 79401.1]
# 200

# %% [markdown]
# #### Gráfico com as cotações do BitCoin

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.plot(lista_cotacoes_btc)
plt.show()
