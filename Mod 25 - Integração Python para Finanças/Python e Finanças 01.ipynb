# %% [markdown]
# ### Vamos analisar o IBOV

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import yfinance as yf
from datetime import datetime

yf.pdr_override()
start_data = datetime(2022, 4, 11)
end_data = datetime(2023, 4, 11)
indices ='^BVSP'

cotacao_ibov = web.get_data_yahoo(indices, start=start_data, end=end_data)
display(cotacao_ibov)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2022-04-11  118320.0  118320.0  116953.0  116953.0   116953.0   9558400
# 2022-04-12  116963.0  118615.0  116054.0  116147.0   116147.0  11406800
# 2022-04-13  116150.0  117329.0  116150.0  116782.0   116782.0  12070500
# 2022-04-14  116781.0  116781.0  115624.0  116182.0   116182.0  10365400
# 2022-04-18  116182.0  116191.0  115177.0  115687.0   115687.0   8404900
# ...              ...       ...       ...       ...        ...       ...
# 2023-04-03  101883.0  101916.0  100651.0  101506.0   101506.0  12794800
# 2023-04-04  101505.0  103056.0  101505.0  101869.0   101869.0  11695800
# 2023-04-05  101869.0  101960.0   99898.0  100978.0   100978.0  13256500
# 2023-04-06  100978.0  101628.0  100443.0  100822.0   100822.0   9818500
# 2023-04-10  100822.0  102196.0  100819.0  101847.0   101847.0         0
#
# [250 rows x 6 columns]

# %% [markdown]
# ### Analisando o Gráfico

# %%
cotacao_ibov['Adj Close'].plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Retorno do IBOV

# %%
retorno_ibov = cotacao_ibov['Adj Close'][-1] / cotacao_ibov['Adj Close'][0] - 1
print('Retorno de {:.2%}'.format(retorno_ibov))
# Out:
# Retorno de -12.92%

# %% [markdown]
# ### Analisando com Média Móvel

# %%
#Média móvel da bolsa
cotacao_ibov['Adj Close'].plot(figsize=(15, 5), label='IBOV')
cotacao_ibov['Adj Close'].rolling(21).mean().plot(label='MM21')
cotacao_ibov['Adj Close'].rolling(34).mean().plot(label='MM34')
plt.legend()
plt.show()
